# %% [markdown]
# # Preprocess data

# %% [markdown]
# We need to fetch the data and get specific columns. We'll then try and create some different tables to see how many records we have for each epitope. This way we can use them for different classifiers or one multiclassifier (combine them into one table).

# %%
import pandas as pd
df = pd.read_csv('./data/vdjdb.txt', sep="\t")

# %%
## Select the columns we need
selected_features = df[['gene','cdr3','v.segm','j.segm','species','mhc.a','mhc.b','mhc.class','antigen.epitope','antigen.species','vdjdb.score']]

# %%
## Select all human data
human_data = selected_features[(selected_features['species'] == 'HomoSapiens') & (selected_features['vdjdb.score'] > 0)]
# Drop duplicate rows
human_data = human_data.drop_duplicates()

# Delete rows with null values
human_data  = human_data.dropna()

# %% [markdown]
# # Create a table for covid data

# %%
## Create a table for covid data
covid_19_table = human_data[human_data['antigen.species'] =='SARS-CoV-2']
covid_19_table
# Out:
#       gene                 cdr3         v.segm      j.segm      species  \
# 419    TRB        CASSQTTKDEQYF     TRBV4-2*01  TRBJ2-7*01  HomoSapiens
# 420    TRB        CASSQGQKDEQYF     TRBV4-2*01  TRBJ2-7*01  HomoSapiens
# 421    TRB      CASSQFTGRKEKLFF      TRBV16*01  TRBJ1-4*01  HomoSapiens
# 422    TRB    CASSLTSGGPTSDTQYF     TRBV5-1*01  TRBJ2-3*01  HomoSapiens
# 423    TRB     CASTTPVTERYNEQFF      TRBV28*01  TRBJ2-1*01  HomoSapiens
# ...    ...                  ...            ...         ...          ...
# 90030  TRB  CASSSYTQRGLDYTGELFF      TRBV27*01  TRBJ2-2*01  HomoSapiens
# 90031  TRB      CSVEDPMGVGTEAFF    TRBV29-1*01  TRBJ1-1*01  HomoSapiens
# 90032  TRA       CLVGENSGGFKTIF       TRAV4*01    TRAJ9*01  HomoSapiens
# 90033  TRA     CAMREGQGNAGNMLTF  TRAV14/DV4*01   TRAJ39*01  HomoSapiens
# 90034  TRB    CASSQDYWGGGADTQYF     TRBV4-1*01  TRBJ2-3*01  HomoSapiens
#
#              mhc.a mhc.b mhc.class antigen.epitope antigen.species  \
# 419    HLA-A*03:01   B2M      MHCI       KTFPPTEPK      SARS-CoV-2
# 420    HLA-A*03:01   B2M      MHCI       KTFPPTEPK      SARS-CoV-2
# 421    HLA-A*03:01   B2M      MHCI       KTFPPTEPK      SARS-CoV-2
# 422    HLA-A*02:01   B2M      MHCI       LLYDANYFL      SARS-CoV-2
# 423    HLA-A*02:01   B2M      MHCI       LLYDANYFL      SARS-CoV-2
# ...            ...   ...       ...             ...             ...
# 90030  HLA-A*24:01   B2M      MHCI       QYIKWPWYI      SARS-CoV-2
# 90031  HLA-A*24:01   B2M      MHCI       QYIKWPWYI      SARS-CoV-2
# 90032  HLA-A*24:01   B2M      MHCI       QYIKWPWYI      SARS-CoV-2
# 90033  HLA-A*24:01   B2M      MHCI       QYIKWPWYI      SARS-CoV-2
# 90034  HLA-A*24:01   B2M      MHCI       QYIKWPWYI      SARS-CoV-2
#
#        vdjdb.score
# 419              1
# 420              1
# 421              1
# 422              1
# 423              1
# ...            ...
# 90030            1
# 90031            1
# 90032            1
# 90033            1
# 90034            1
#
# [724 rows x 11 columns]

# %% [markdown]
# # Create a table for flu data

# %%
## Create a table for flu
flu_table = human_data[human_data['antigen.species'] =='InfluenzaA']
flu_table
# Out:
#       gene              cdr3       v.segm      j.segm      species  \
# 1273   TRA   CAVSESPFGNEKLTF   TRAV8-4*01   TRAJ48*01  HomoSapiens
# 1274   TRB    CASSSTGLPYGYTF    TRBV28*01  TRBJ1-2*01  HomoSapiens
# 1277   TRA   CAVSESPFGNEKLTF   TRAV8-4*01   TRAJ48*01  HomoSapiens
# 1278   TRB    CASSSTGLPYGYTF    TRBV28*01  TRBJ1-2*01  HomoSapiens
# 1287   TRA      CAGAGSQGNLIF    TRAV27*01   TRAJ42*01  HomoSapiens
# ...    ...               ...          ...         ...          ...
# 82102  TRB   CSAGGWDRVNQPQHF  TRBV20-1*01  TRBJ1-5*01  HomoSapiens
# 82103  TRB   CASSESQTGDYEQYF  TRBV25-1*01  TRBJ2-7*01  HomoSapiens
# 82104  TRB  CATSDSTSGGTDTQYF  TRBV24-1*01  TRBJ2-3*01  HomoSapiens
# 82105  TRB   CASSFSAEATGELFF     TRBV9*01  TRBJ2-2*01  HomoSapiens
# 82116  TRB   CASSFSAEATGELFF  TRBV25-1*01  TRBJ2-2*01  HomoSapiens
#
#                   mhc.a              mhc.b mhc.class antigen.epitope  \
# 1273   HLA-DRA*01:02:03  HLA-DRB1*01:01:01     MHCII   PKYVKQNTLKLAT
# 1274   HLA-DRA*01:02:03  HLA-DRB1*01:01:01     MHCII   PKYVKQNTLKLAT
# 1277   HLA-DRA*01:02:03  HLA-DRB1*04:01:01     MHCII   PKYVKQNTLKLAT
# 1278   HLA-DRA*01:02:03  HLA-DRB1*04:01:01     MHCII   PKYVKQNTLKLAT
# 1287     HLA-A*02:01:48                B2M      MHCI       GILGFVFTL
# ...                 ...                ...       ...             ...
# 82102        HLA-DRA*01        HLA-DRB1*01     MHCII   PKYVKQNTLKLAT
# 82103        HLA-DRA*01        HLA-DRB1*01     MHCII   PKYVKQNTLKLAT
# 82104        HLA-DRA*01        HLA-DRB1*01     MHCII   PKYVKQNTLKLAT
# 82105        HLA-DRA*01        HLA-DRB1*01     MHCII   PKYVKQNTLKLAT
# 82116        HLA-DRA*01        HLA-DRB1*01     MHCII   PKYVKQNTLKLAT
#
#       antigen.species  vdjdb.score
# 1273       InfluenzaA            3
# 1274       InfluenzaA            3
# 1277       InfluenzaA            3
# 1278       InfluenzaA            3
# 1287       InfluenzaA            3
# ...               ...          ...
# 82102      InfluenzaA            3
# 82103      InfluenzaA            3
# 82104      InfluenzaA            3
# 82105      InfluenzaA            1
# 82116      InfluenzaA            1
#
# [756 rows x 11 columns]

# %% [markdown]
# # Create a table for cancer data

# %%
## Create a table for cancer
cancer_table =  human_data[human_data['antigen.species'] =='HomoSapiens']

# %%
cancer_table
# Out:
#       gene             cdr3       v.segm      j.segm      species  \
# 682    TRA  CAVAGYGGSQGNLIF  TRAV12-2*01   TRAJ42*01  HomoSapiens
# 683    TRB   CASSPQGLGTEAFF    TRBV28*01  TRBJ1-1*01  HomoSapiens
# 1297   TRA   CALSGGDSSYKLIF   TRAV9-2*01   TRAJ12*01  HomoSapiens
# 1298   TRB  CASSLADRVNTEAFF   TRBV5-1*01  TRBJ1-1*01  HomoSapiens
# 1301   TRA  CAVRPTSGGSYIPTF    TRAV21*01    TRAJ6*01  HomoSapiens
# ...    ...              ...          ...         ...          ...
# 84140  TRB    CASSIQRNYGYTF   TRBV6-5*01  TRBJ1-2*01  HomoSapiens
# 84141  TRB  CASSATFNDNEKLFF  TRBV10-1*01  TRBJ1-4*01  HomoSapiens
# 84142  TRB     CATSDFGTEAFF  TRBV24-1*01  TRBJ1-1*01  HomoSapiens
# 84144  TRB   CASSQGQLAGGLVF   TRBV4-1*01  TRBJ2-4*01  HomoSapiens
# 84145  TRB  CASSGSKGAAGELFF  TRBV11-2*01  TRBJ2-2*01  HomoSapiens
#
#                   mhc.a              mhc.b mhc.class antigen.epitope  \
# 682            HLA-A*02                B2M      MHCI      ELAGIGILTV
# 683            HLA-A*02                B2M      MHCI      ELAGIGILTV
# 1297   HLA-DRA*01:02:03  HLA-DRB5*01:01:01     MHCII  VHFFKNIVTPRTPG
# 1298   HLA-DRA*01:02:03  HLA-DRB5*01:01:01     MHCII  VHFFKNIVTPRTPG
# 1301     HLA-A*02:01:48                B2M      MHCI       SLLMWITQV
# ...                 ...                ...       ...             ...
# 84140          HLA-A*02                B2M      MHCI      NLSALGIFST
# 84141          HLA-A*02                B2M      MHCI      NLSALGIFST
# 84142          HLA-A*02                B2M      MHCI      NLSALGIFST
# 84144          HLA-A*02                B2M      MHCI      NLSALGIFST
# 84145          HLA-A*02                B2M      MHCI      NLSALGIFST
#
#       antigen.species  vdjdb.score
# 682       HomoSapiens            1
# 683       HomoSapiens            1
# 1297      HomoSapiens            3
# 1298      HomoSapiens            3
# 1301      HomoSapiens            3
# ...               ...          ...
# 84140     HomoSapiens            1
# 84141     HomoSapiens            1
# 84142     HomoSapiens            1
# 84144     HomoSapiens            1
# 84145     HomoSapiens            1
#
# [922 rows x 11 columns]

# %% [markdown]
# # Create a table for CMV data

# %%
## Create a table for CMV
cmv_table = human_data[human_data['antigen.species'] =='CMV']

# %%
cmv_table
# Out:
#       gene                    cdr3       v.segm      j.segm      species  \
# 963    TRB         CASSYQTGAAYGYTF   TRBV6-5*01  TRBJ1-2*01  HomoSapiens
# 964    TRB        CASRSAQRGFTETQYF    TRBV28*01  TRBJ2-5*01  HomoSapiens
# 965    TRB  CASSSSTGTGRCLLPNNTEAFF  TRBV11-3*01  TRBJ1-1*01  HomoSapiens
# 966    TRB        CASSPVTGQGFYGYTF   TRBV6-5*01  TRBJ1-2*01  HomoSapiens
# 968    TRB        CASSEEPSGGAYEQYF   TRBV6-1*01  TRBJ2-7*01  HomoSapiens
# ...    ...                     ...          ...         ...          ...
# 83846  TRB          CASSWAPNTGELFF  TRBV12-3*01  TRBJ2-2*01  HomoSapiens
# 83847  TRB         CSATPARASNTEAFF  TRBV20-1*01  TRBJ1-1*01  HomoSapiens
# 83848  TRB          CSARDPQGVTEAFF  TRBV20-1*01  TRBJ1-1*01  HomoSapiens
# 83849  TRB        CSARDSSGGAKNIQYF  TRBV20-1*01  TRBJ2-4*01  HomoSapiens
# 83850  TRA         CAASIGDFGNEKLTF  TRAV13-1*01   TRAJ48*01  HomoSapiens
#
#              mhc.a mhc.b mhc.class antigen.epitope antigen.species  \
# 963    HLA-A*02:01   B2M      MHCI       NLVPMVATV             CMV
# 964    HLA-A*02:01   B2M      MHCI       NLVPMVATV             CMV
# 965    HLA-A*02:01   B2M      MHCI       NLVPMVATV             CMV
# 966    HLA-A*02:01   B2M      MHCI       NLVPMVATV             CMV
# 968    HLA-A*02:01   B2M      MHCI       NLVPMVATV             CMV
# ...            ...   ...       ...             ...             ...
# 83846  HLA-B*07:02   B2M      MHCI     RPHERNGFTVL             CMV
# 83847  HLA-B*07:02   B2M      MHCI     RPHERNGFTVL             CMV
# 83848  HLA-B*07:02   B2M      MHCI     RPHERNGFTVL             CMV
# 83849  HLA-B*07:02   B2M      MHCI     RPHERNGFTVL             CMV
# 83850  HLA-B*07:02   B2M      MHCI     RPHERNGFTVL             CMV
#
#        vdjdb.score
# 963              3
# 964              1
# 965              1
# 966              1
# 968              1
# ...            ...
# 83846            1
# 83847            1
# 83848            1
# 83849            1
# 83850            1
#
# [1286 rows x 11 columns]
