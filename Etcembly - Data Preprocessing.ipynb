# %%
import pandas as pd
import numpy as np 
from IPython.display import display
import json

# %% [markdown]
# ## Task 1: Get data columns
# 1.	Get the following columns: Gene, CDR3, V, J, MHC A, MHC B, MHC Class, Epitope, EPitope gene, Epitope species, Score (minimum 1 or more.)
# 2.	Limit data to: Human species, TRA, TRB, and Paired Only.
# 3.	Produce one table for Covid-19, one for Flu, and one for Cancer (we can combine them later if we want to).
# 4.	Remove or add meaningful placeholders to any rows that have empty values.

# %% [markdown]
# ## 1.	Get the following columns: Gene, CDR3, V, J, MHC A, MHC B, MHC Class, Epitope, EPitope gene, Epitope species, Score (minimum 1 or more.)

# %%
df = pd.read_csv("../Task/Github/vdjdb-2023-06-01/vdjdb.txt", delimiter="\t")
df.head(2)
# Out:
#    complex.id gene                  cdr3       v.segm      j.segm  \
# 0           1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1           1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
#
#        species     mhc.a mhc.b mhc.class antigen.epitope  ... antigen.species  \
# 0  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
# 1  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
#
#     reference.id                                             method  \
# 0  PMID:15596521  {"frequency": "", "identification": "tetramer-...
# 1  PMID:15596521  {"frequency": "", "identification": "tetramer-...
#
#                                                 meta  \
# 0  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1  {"cell.subset": "CD8+", "clone.id": "", "donor...
#
#                                              cdr3fix vdjdb.score  web.method  \
# 0  {"cdr3": "CIVRAPGRADMRF", "cdr3_old": "CIVRAPG...           2        sort
# 1  {"cdr3": "CASSYLPGQGDHYSNQPQHF", "cdr3_old": "...           2        sort
#
#   web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0         sanger             no               no
# 1         sanger             no               no
#
# [2 rows x 21 columns]

# %%
# Select the columns we need
selected_features = ['gene','cdr3','v.segm','j.segm','species','mhc.a','mhc.b','mhc.class','antigen.epitope','antigen.species','vdjdb.score']

df1 = df[selected_features]
df1.head()
# Out:
#   gene                  cdr3       v.segm      j.segm      species     mhc.a  \
# 0  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01  HomoSapiens  HLA-B*08
# 1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens  HLA-B*08
# 2  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens  HLA-B*08
# 3  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01  HomoSapiens  HLA-B*08
# 4  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens  HLA-B*08
#
#   mhc.b mhc.class antigen.epitope antigen.species  vdjdb.score
# 0   B2M      MHCI        FLKEKGGL           HIV-1            2
# 1   B2M      MHCI        FLKEKGGL           HIV-1            2
# 2   B2M      MHCI        FLKEKGGL           HIV-1            2
# 3   B2M      MHCI        FLKEKGGL           HIV-1            2
# 4   B2M      MHCI        FLKEKGGL           HIV-1            2

# %%
df1.shape
# Out:
# (92771, 11)

# %%
df2 = df1[df1["vdjdb.score"]>=1]
df2.head()
# Out:
#   gene                  cdr3       v.segm      j.segm      species     mhc.a  \
# 0  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01  HomoSapiens  HLA-B*08
# 1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens  HLA-B*08
# 2  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens  HLA-B*08
# 3  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01  HomoSapiens  HLA-B*08
# 4  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens  HLA-B*08
#
#   mhc.b mhc.class antigen.epitope antigen.species  vdjdb.score
# 0   B2M      MHCI        FLKEKGGL           HIV-1            2
# 1   B2M      MHCI        FLKEKGGL           HIV-1            2
# 2   B2M      MHCI        FLKEKGGL           HIV-1            2
# 3   B2M      MHCI        FLKEKGGL           HIV-1            2
# 4   B2M      MHCI        FLKEKGGL           HIV-1            2

# %%
df2.shape
# Out:
# (12414, 11)

# %% [markdown]
# ## 2.	Limit data to: Human species, TRA, TRB, and Paired Only.

# %%
df3 = df2.copy()

# %% [markdown]
# # 3.	Produce one table for Covid-19, one for Flu, and one for Cancer. (we can combine them later if we want to).

# %%
**Flu (Influenza):**
- Influenza A

**COVID-19 (SARS-CoV-2):**
- SARS-CoV-2

**Cancer:**

1. *EBV (Epstein-Barr Virus)*: Associated with several types of cancer, including Hodgkin's lymphoma, Burkitt's lymphoma, gastric cancer, and nasopharyngeal carcinoma.
2. *HTLV-1 (Human T-cell Lymphotropic Virus Type 1)*: Associated with adult T-cell leukemia/lymphoma (ATLL).
3. *HCV (Hepatitis C Virus)*: Chronic infection can lead to liver cancer, specifically hepatocellular carcinoma.
4. *HPV (Human Papillomavirus)*: Certain types of HPV are strongly associated with cervical cancer, as well as other types of cancer including anal, oropharyngeal, penile, vulvar, and vaginal cancers.
5. *HHV (Human Herpesvirus)*: Depending on the specific type, some HHVs can be associated with cancer. For example, HHV-8 is associated with Kaposi's sarcoma.
6. *MCPyV (Merkel Cell Polyomavirus)*: Linked to Merkel cell carcinoma, a rare but aggressive form of skin cancer.
# Out:
#   File "/var/folders/h9/d81qv1gj76sdb7w_8sq021sh0000gn/T/ipykernel_4045/1972989061.py", line 1
#     **Flu (Influenza):**
#     ^
# SyntaxError: invalid syntax

# %%
species_dict = {
    'Flu': ['InfluenzaA'],
    'COVID-19': ['SARS-CoV-2'],
    'Cancer': ['EBV', 'HTLV-1', "HCV", 'MCPyV', 'HPV-16']
}

# %%
flu_data = df3[df3["antigen.species"]=='InfluenzaA']
flu_data.head()
# Out:
#      gene             cdr3      v.segm      j.segm      species  \
# 1273  TRA  CAVSESPFGNEKLTF  TRAV8-4*01   TRAJ48*01  HomoSapiens
# 1274  TRB   CASSSTGLPYGYTF   TRBV28*01  TRBJ1-2*01  HomoSapiens
# 1277  TRA  CAVSESPFGNEKLTF  TRAV8-4*01   TRAJ48*01  HomoSapiens
# 1278  TRB   CASSSTGLPYGYTF   TRBV28*01  TRBJ1-2*01  HomoSapiens
# 1287  TRA     CAGAGSQGNLIF   TRAV27*01   TRAJ42*01  HomoSapiens
#
#                  mhc.a              mhc.b mhc.class antigen.epitope  \
# 1273  HLA-DRA*01:02:03  HLA-DRB1*01:01:01     MHCII   PKYVKQNTLKLAT
# 1274  HLA-DRA*01:02:03  HLA-DRB1*01:01:01     MHCII   PKYVKQNTLKLAT
# 1277  HLA-DRA*01:02:03  HLA-DRB1*04:01:01     MHCII   PKYVKQNTLKLAT
# 1278  HLA-DRA*01:02:03  HLA-DRB1*04:01:01     MHCII   PKYVKQNTLKLAT
# 1287    HLA-A*02:01:48                B2M      MHCI       GILGFVFTL
#
#      antigen.species  vdjdb.score
# 1273      InfluenzaA            3
# 1274      InfluenzaA            3
# 1277      InfluenzaA            3
# 1278      InfluenzaA            3
# 1287      InfluenzaA            3

# %%
covid19_data = df3[df3["antigen.species"]=='SARS-CoV-2']
covid19_data.head()
# Out:
#     gene               cdr3      v.segm      j.segm      species        mhc.a  \
# 419  TRB      CASSQTTKDEQYF  TRBV4-2*01  TRBJ2-7*01  HomoSapiens  HLA-A*03:01
# 420  TRB      CASSQGQKDEQYF  TRBV4-2*01  TRBJ2-7*01  HomoSapiens  HLA-A*03:01
# 421  TRB    CASSQFTGRKEKLFF   TRBV16*01  TRBJ1-4*01  HomoSapiens  HLA-A*03:01
# 422  TRB  CASSLTSGGPTSDTQYF  TRBV5-1*01  TRBJ2-3*01  HomoSapiens  HLA-A*02:01
# 423  TRB   CASTTPVTERYNEQFF   TRBV28*01  TRBJ2-1*01  HomoSapiens  HLA-A*02:01
#
#     mhc.b mhc.class antigen.epitope antigen.species  vdjdb.score
# 419   B2M      MHCI       KTFPPTEPK      SARS-CoV-2            1
# 420   B2M      MHCI       KTFPPTEPK      SARS-CoV-2            1
# 421   B2M      MHCI       KTFPPTEPK      SARS-CoV-2            1
# 422   B2M      MHCI       LLYDANYFL      SARS-CoV-2            1
# 423   B2M      MHCI       LLYDANYFL      SARS-CoV-2            1

# %%
# ['EBV', 'HTLV-1', "HCV", 'MCPyV', 'HPV-16']

cancer_data = df3[(
    df3["antigen.species"]=='EBV') |
    (df3["antigen.species"]=='HTLV-1') |
    (df3["antigen.species"]=='HCV') |
    (df3["antigen.species"]=='MCPyV') |
    (df3["antigen.species"]=='HPV-16') 
]
cancer_data.sample(5)
# Out:
#       gene             cdr3       v.segm      j.segm      species  \
# 17631  TRB  CASRTLLGGASEQYF    TRBV27*01  TRBJ2-7*01  HomoSapiens
# 21870  TRB  CSARPIDSSNQPQHF  TRBV20-1*01  TRBJ1-5*01  HomoSapiens
# 75335  TRB     CSPGTDLYEQYF  TRBV29-1*01  TRBJ2-7*01  HomoSapiens
# 78688  TRB  CASRDILTSYNEQFF     TRBV2*01  TRBJ2-1*01  HomoSapiens
# 21633  TRB   CASSLGTQTYEQYF    TRBV27*01  TRBJ2-7*01  HomoSapiens
#
#              mhc.a mhc.b mhc.class antigen.epitope antigen.species  \
# 17631  HLA-A*02:01   B2M      MHCI       YVLDHLIVV             EBV
# 21870     HLA-A*01   B2M      MHCI       ATDALMTGY             HCV
# 75335  HLA-A*02:01   B2M      MHCI       GLCTLVAML             EBV
# 78688  HLA-A*01:01   B2M      MHCI       ATDALMTGY             HCV
# 21633     HLA-A*02   B2M      MHCI       CINGVCWTV             HCV
#
#        vdjdb.score
# 17631            1
# 21870            1
# 75335            1
# 78688            1
# 21633            1

# %% [markdown]
# # 4.	Remove or add meaningful placeholders to any rows that have empty values.

# %% [markdown]
# Assigning random values for imputing missing data was not considered, due sensitive medical information within the dataset. Therefore, null values are replaced with the term "missing."

# %%
df4 = df3.fillna("missing")

# %%
df4.isnull().sum()
# Out:
# gene               0
# cdr3               0
# v.segm             0
# j.segm             0
# species            0
# mhc.a              0
# mhc.b              0
# mhc.class          0
# antigen.epitope    0
# antigen.species    0
# vdjdb.score        0
# dtype: int64
