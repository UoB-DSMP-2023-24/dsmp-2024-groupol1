# %%
IS_COLAB = True

# !pip install tcrdist3
# !pip install umap-learn
# !pip install umap-learn[plot]

if IS_COLAB:
    from google.colab import drive

    drive.mount('/content/drive')
    # %ls
    # %cd drive/MyDrive/dsmp-2024-groupol1/
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# drive/  sample_data/
# /content/drive/MyDrive/dsmp-2024-groupol1

# %%
import pandas as pd
from utilities.tcbert import *

df = pd.read_csv('./data/vdjdb.txt', sep="\t")

model = BertTcr(input_data=df)

model.run_model()
model.reduce_dimensionality(title = 'Beta chain compact representation - TCRBert')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
model.record_performance()
# Out:
# Adjusted mutual information score:  0.14587510370953868
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from utilities.dist3 import Dist3
import pandas as pd

df = pd.read_csv('./data/vdjdb.txt', sep="\t")

dist_model = Dist3(input_data=df)

dist_model.run_model()
dist_model.reduce_dimensionality(title = 'Beta chain compact representation by antigen specificity')
dist_model.record_performance()
# Out:
# /content/drive/MyDrive/dsmp-2024-groupol1/utilities/dist3.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _TRA.rename(columns={'cdr3':'cdr3_a_aa',
# /content/drive/MyDrive/dsmp-2024-groupol1/utilities/dist3.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _TRB.rename(columns={'cdr3':'cdr3_b_aa',
# /usr/local/lib/python3.10/dist-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# ...

# %%
dist_model = Dist3(input_data=df)

dist_model.run_model(chains = ['alpha'])
dist_model.reduce_dimensionality(title = 'Alpha chain compact representation by antigen specificity')
dist_model.record_performance()
# Out:
# /content/drive/MyDrive/dsmp-2024-groupol1/utilities/dist3.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _TRA.rename(columns={'cdr3':'cdr3_a_aa',
# /content/drive/MyDrive/dsmp-2024-groupol1/utilities/dist3.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _TRB.rename(columns={'cdr3':'cdr3_b_aa',
# /usr/local/lib/python3.10/dist-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# ...

# %%
dist_model = Dist3(input_data=df)

dist_model.run_model(chains = ['alpha', 'beta'])
dist_model.reduce_dimensionality(title = 'alpha-beta chain compact representation by antigen specificity')
dist_model.record_performance()
# Out:
# /content/drive/MyDrive/dsmp-2024-groupol1/utilities/dist3.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _TRA.rename(columns={'cdr3':'cdr3_a_aa',
# /content/drive/MyDrive/dsmp-2024-groupol1/utilities/dist3.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _TRB.rename(columns={'cdr3':'cdr3_b_aa',
# /usr/local/lib/python3.10/dist-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# ...
